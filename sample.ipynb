# %%
import pickle
with open('mushroom_classification.pkl','rb') as f:
    model = pickle.load(f)

# %%
import pandas as pd

# %%
df = pd.read_csv('testing.csv',header=0)
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises   odor  gill-attachment  \
# 0    0.0        0.4     1.000000   0.000000      0.0  0.875              1.0
# 1    1.0        0.4     1.000000   1.000000      0.0  0.000              1.0
# 2    1.0        0.0     1.000000   0.888889      0.0  0.125              1.0
# 3    0.0        0.4     0.666667   0.888889      0.0  0.875              1.0
# 4    1.0        0.4     1.000000   0.333333      1.0  0.750              1.0
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0           0.0        1.0    0.000000  ...                       1.0
# 1           0.0        0.0    0.000000  ...                       1.0
# 2           0.0        0.0    0.090909  ...                       1.0
# 3           0.0        1.0    0.090909  ...                       1.0
# 4           1.0        0.0    0.000000  ...                       1.0
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
input_ = df.iloc[:,1:]

df['yped'] = model.predict(input_)

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises   odor  \
# 0       0.0        0.4     1.000000   0.000000      0.0  0.875
# 1       1.0        0.4     1.000000   1.000000      0.0  0.000
# 2       1.0        0.0     1.000000   0.888889      0.0  0.125
# 3       0.0        0.4     0.666667   0.888889      0.0  0.875
# 4       1.0        0.4     1.000000   0.333333      1.0  0.750
# ...     ...        ...          ...        ...      ...    ...
# 8119    1.0        0.8     1.000000   0.000000      1.0  0.750
# 8120    1.0        0.4     1.000000   0.000000      1.0  0.750
# 8121    1.0        0.6     1.000000   0.000000      1.0  0.750
# 8122    0.0        0.8     0.666667   0.000000      1.0  0.375
# 8123    1.0        0.4     1.000000   0.000000      1.0  0.750
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                 1.0           0.0        1.0    0.000000  ...
# 1                 1.0           0.0        0.0    0.000000  ...
# ...
