# %%
# Loading the dataset
import pandas as pd
df=pd.read_csv("mushrooms.csv",header=0)
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
df['cap-shape']=df['cap-shape'].map({'b':1,'c':2,'x':3,'f':4,'k':5,'s':6})
df.head()
# Out:
#   class  cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p          3           s         n       t    p               f
# 1     e          3           s         y       t    a               f
# 2     e          1           s         w       t    l               f
# 3     p          3           y         w       t    p               f
# 4     e          3           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df['cap-surface']=df['cap-surface'].map({'f':1,'g':2,'y':3,'s':4})
df['cap-color']=df['cap-color'].map({'n':1,'b':2,'c':3,'g':4,'r':5,'p':6,'u':7,'e':8,'w':9,'y':10})
df.head()
# Out:
#   class  cap-shape  cap-surface  cap-color bruises odor gill-attachment  \
# 0     p          3            4          1       t    p               f
# 1     e          3            4         10       t    a               f
# 2     e          1            4          9       t    l               f
# 3     p          3            3          9       t    p               f
# 4     e          3            4          4       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df['odor']=df['odor'].map({'a':1,'l':2,'c':3,'y':4,'f':5,'m':6,'n':7,'p':8,'s':9})
df['bruises']=df['bruises'].map({'t':1,'f':2,})
df.head()
# Out:
#   class  cap-shape  cap-surface  cap-color  bruises  odor gill-attachment  \
# 0     p          3            4          1        1     8               f
# 1     e          3            4         10        1     1               f
# 2     e          1            4          9        1     2               f
# 3     p          3            3          9        1     8               f
# 4     e          3            4          4        2     7               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      3.491876     2.742984     5.323486     1.584441     5.788282
# std       0.901287     1.179629     3.444391     0.492848     1.983678
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       3.000000     1.000000     1.000000     1.000000     5.000000
# 50%       3.000000     3.000000     4.000000     2.000000     7.000000
# 75%       4.000000     4.000000     9.000000     2.000000     7.000000
# max       6.000000     4.000000    10.000000     2.000000     9.000000

# %%
df['gill-attachment']=df['gill-attachment'].map({'a':1,'d':2,'f':3,'n':4})

# %%
df['class']=df['class'].map({'p':1,'e':2,})
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          3            4          1        1     8                3
# 1      2          3            4         10        1     1                3
# 2      2          1            4          9        1     2                3
# 3      1          3            3          9        1     8                3
# 4      2          3            4          4        2     7                3
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df['gill-spacing']=df['gill-spacing'].map({'c':1,'w':2,'d':3})
df['gill-size']=df['gill-size'].map({'b':1,'n':2,})
df['gill-color']=df['gill-color'].map({'k':1,'n':2,'b':3,'h':4,'g':5,'r':6,'o':7,'p':8,'u':9,'e':10,'w':11,'y':12})
df['stalk-shape']=df['stalk-shape'].map({'e':1,'t':2,})
df['stalk-root']=df['stalk-root'].map({'b':1,'c':2,'u':3,'e':4,'z':5,'r':6,'?':7})
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          3            4          1        1     8                3
# 1      2          3            4         10        1     1                3
# 2      2          1            4          9        1     2                3
# 3      1          3            3          9        1     8                3
# 4      2          3            4          4        2     7                3
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             1          2           1  ...                         s
# 1             1          1           1  ...                         s
# 2             1          1           2  ...                         s
# 3             1          2           2  ...                         s
# 4             2          1           1  ...                         s
#
#    stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                       w                      w         p          w
# 1                       w                      w         p          w
# 2                       w                      w         p          w
# 3                       w                      w         p          w
# 4                       w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df['stalk-color-above-ring']=df['stalk-color-above-ring'].map({'n':1,'b':2,'c':3,'g':4,'o':5,'p':6,'e':7,'w':8,'y':9})
df['stalk-color-below-ring']=df['stalk-color-below-ring'].map({'n':1,'b':2,'c':3,'g':4,'o':5,'p':6,'e':7,'w':8,'y':9})
df['veil-type']=df['veil-type'].map({'p':1,'u':2})
df['veil-color']=df['veil-color'].map({'n':1,'o':2,'w':3,'y':4})
df['ring-number']=df['ring-number'].map({'n':1,'o':2,'t':3})
df['ring-type']=df['ring-type'].map({'c':1,'e':2,'f':3,'l':4,'n':5,'p':6,'s':7,'z':8})
df['spore-print-color']=df['spore-print-color'].map({'k':1,'n':2,'b':3,'h':4,'r':5,'o':6,'u':7,'w':8,'y':9})
df['population']=df['population'].map({'a':1,'c':2,'n':3,'s':4,'v':5,'y':6})
df['habitat']=df['habitat'].map({'g':1,'l':2,'m':3,'p':4,'u':5,'w':6,'d':7})
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          3            4          1        1     8                3
# 1      2          3            4         10        1     1                3
# 2      2          1            4          9        1     2                3
# 3      1          3            3          9        1     8                3
# 4      2          3            4          4        2     7                3
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             1          2           1  ...                         s
# 1             1          1           1  ...                         s
# 2             1          1           2  ...                         s
# 3             1          2           2  ...                         s
# 4             2          1           1  ...                         s
#
#    stalk-color-above-ring stalk-color-below-ring veil-type  veil-color  \
# 0                       8                      8         1           3
# 1                       8                      8         1           3
# 2                       8                      8         1           3
# 3                       8                      8         1           3
# 4                       8                      8         1           3
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            2          6                  1           4        5
# 1            2          6                  2           3        1
# 2            2          6                  2           3        3
# 3            2          6                  1           4        5
# 4            2          2                  2           1        1
#
# [5 rows x 23 columns]

# %%
df['stalk-surface-above-ring']=df['stalk-surface-above-ring'].map({'f':1,'y':2,'k':3,'s':4})
df['stalk-surface-below-ring']=df['stalk-surface-below-ring'].map({'f':1,'y':2,'k':3,'s':4})

# %%
y=df['class']
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    1
# 4    2
# Name: class, dtype: int64

# %%
x=df.drop(['class'],axis='columns')
x.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          3            4          1        1     8                3
# 1          3            4         10        1     1                3
# 2          1            4          9        1     2                3
# 3          3            3          9        1     8                3
# 4          3            4          4        2     7                3
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             1          2           1            1  ...
# 1             1          1           1            1  ...
# 2             1          1           2            1  ...
# 3             1          2           2            1  ...
# 4             2          1           1            2  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         4                       8                       8
# 1                         4                       8                       8
# 2                         4                       8                       8
# 3                         4                       8                       8
# 4                         4                       8                       8
#
#    veil-type  veil-color  ring-number  ring-type  spore-print-color  \
# 0          1           3            2          6                  1
# 1          1           3            2          6                  2
# 2          1           3            2          6                  2
# 3          1           3            2          6                  1
# 4          1           3            2          2                  2
#
#    population  habitat
# 0           4        5
# 1           3        1
# 2           3        3
# 3           4        5
# 4           1        1
#
# [5 rows x 22 columns]

# %%
feature_name = df.columns

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler((0,1))
df = scaler.fit_transform(df)
df = pd.DataFrame(df,columns=feature_name)
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises   odor  \
# 0       0.0        0.4     1.000000   0.000000      0.0  0.875
# 1       1.0        0.4     1.000000   1.000000      0.0  0.000
# 2       1.0        0.0     1.000000   0.888889      0.0  0.125
# 3       0.0        0.4     0.666667   0.888889      0.0  0.875
# 4       1.0        0.4     1.000000   0.333333      1.0  0.750
# ...     ...        ...          ...        ...      ...    ...
# 8119    1.0        0.8     1.000000   0.000000      1.0  0.750
# 8120    1.0        0.4     1.000000   0.000000      1.0  0.750
# 8121    1.0        0.6     1.000000   0.000000      1.0  0.750
# 8122    0.0        0.8     0.666667   0.000000      1.0  0.375
# 8123    1.0        0.4     1.000000   0.000000      1.0  0.750
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                 1.0           0.0        1.0    0.000000  ...
# 1                 1.0           0.0        0.0    0.000000  ...
# 2                 1.0           0.0        0.0    0.090909  ...
# 3                 1.0           0.0        1.0    0.090909  ...
# 4                 1.0           1.0        0.0    0.000000  ...
# ...               ...           ...        ...         ...  ...
# 8119              0.0           0.0        0.0    1.000000  ...
# 8120              0.0           0.0        0.0    1.000000  ...
# 8121              0.0           0.0        0.0    0.090909  ...
# 8122              1.0           0.0        1.0    0.181818  ...
# 8123              0.0           0.0        0.0    1.000000  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                     1.000000                   0.875
# 1                     1.000000                   0.875
# 2                     1.000000                   0.875
# 3                     1.000000                   0.875
# 4                     1.000000                   0.875
# ...                        ...                     ...
# 8119                  1.000000                   0.500
# 8120                  1.000000                   0.500
# 8121                  1.000000                   0.500
# 8122                  0.666667                   0.875
# 8123                  1.000000                   0.500
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                      0.875        0.0    0.666667          0.5        1.0
# 1                      0.875        0.0    0.666667          0.5        1.0
# 2                      0.875        0.0    0.666667          0.5        1.0
# 3                      0.875        0.0    0.666667          0.5        1.0
# 4                      0.875        0.0    0.666667          0.5        0.0
# ...                      ...        ...         ...          ...        ...
# 8119                   0.500        0.0    0.333333          0.5        1.0
# 8120                   0.500        0.0    0.000000          0.5        1.0
# 8121                   0.500        0.0    0.333333          0.5        1.0
# 8122                   0.875        0.0    0.666667          0.5        0.0
# 8123                   0.500        0.0    0.333333          0.5        1.0
#
#       spore-print-color  population   habitat
# 0                 0.000         0.6  0.666667
# 1                 0.125         0.4  0.000000
# 2                 0.125         0.4  0.333333
# 3                 0.000         0.6  0.666667
# 4                 0.125         0.0  0.000000
# ...                 ...         ...       ...
# 8119              0.250         0.2  0.166667
# 8120              0.250         0.8  0.166667
# 8121              0.250         0.2  0.166667
# 8122              0.875         0.8  0.166667
# 8123              0.625         0.2  0.166667
#
# [8124 rows x 23 columns]

# %%
import seaborn as sns


# Calculate correlation matrix
correlation = df.corr()

# Create heatmap
sns.heatmap(correlation, center=0, cmap="bwr")
# Out:
# <Axes: >

# %%
df.drop(['veil-type','habitat','cap-color','odor','gill-attachment','stalk-shape','stalk-root','stalk-surface-below-ring','veil-color'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   float64
#  1   cap-shape                 8124 non-null   float64
#  2   cap-surface               8124 non-null   float64
#  3   bruises                   8124 non-null   float64
#  4   gill-spacing              8124 non-null   float64
#  5   gill-size                 8124 non-null   float64
#  6   gill-color                8124 non-null   float64
#  7   stalk-surface-above-ring  8124 non-null   float64
#  8   stalk-color-above-ring    8124 non-null   float64
#  9   stalk-color-below-ring    8124 non-null   float64
#  10  ring-number               8124 non-null   float64
#  11  ring-type                 8124 non-null   float64
#  12  spore-print-color         8124 non-null   float64
#  13  population                8124 non-null   float64
# dtypes: float64(14)
# memory usage: 888.7 KB

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)

# %%
y_pred
# Out:
# array([1, 1, 2, ..., 2, 1, 1], dtype=int64)

# %%
y_test
# Out:
# 5590    1
# 4443    1
# 5804    2
# 3755    1
# 7370    2
#        ..
# 629     2
# 5219    2
# 7153    2
# 6949    1
# 3201    1
# Name: class, Length: 3250, dtype: int64

# %%
from sklearn.metrics import confusion_matrix,recall_score

# %%
print("for train data")
print(confusion_matrix(y_train,y_train_pred))
print("for testing data")
print(confusion_matrix(y_test,y_pred))
# Out:
# for train data
# [[2315    0]
#  [   0 2559]]
# for testing data
# [[1601    0]
#  [   0 1649]]

# %%
print("for train data")
print(recall_score(y_train,y_train_pred))

print("for test data")
print(recall_score(y_test,y_pred))
# Out:
# for train data
# 1.0
# for test data
# 1.0

# %%
import pickle
with open("mushroom_classification.pkl",'wb') as f:
    pickle.dump(model,f)
    f.close()
